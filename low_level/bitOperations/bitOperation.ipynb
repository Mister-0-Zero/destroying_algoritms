# %%
a = 11 #1011
b = 5 #101

print(f"bit and: {a & b}")
print(f"bit or: {a | b}")
print(f"bit xor: {b ^ a}")
print(f"bit not a: {~a}, bit not b: {~b}")
print(f"bit shift left: {a << 1}")
print(f"bit shift right: {a >> 1}")
# Out:
# bit and: 1
# bit or: 15
# bit xor: 14
# bit not a: -12, bit not b: -6
# bit shift left: 22
# bit shift right: 5
